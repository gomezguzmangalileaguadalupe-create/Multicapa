# %% [markdown]
# <a href="https://colab.research.google.com/github/gomezguzmangalileaguadalupe-create/Multicapa/blob/main/Clasificaci%C3%B3n_de_un_candidato_a_un_empleo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# Generar dataset sintético con diferentes rangos por habilidad
n_muestras = 5000
# Habilidades técnicas: 70-100
tec = np.random.randint(70, 101, (n_muestras, 6))
# Habilidades matemáticas: 60-90
mat = np.random.randint(60, 91, (n_muestras, 6))
# Habilidades psicológicas: 50-85
psi = np.random.randint(50, 86, (n_muestras, 6))
# Nombres de columnas
columnas = [
    'python', 'sql', 'visualizacion_datos', 'excel', 'manejo_apis', 'nube',
    'estadistica', 'probabilidad', 'algebra_lineal', 'calculo', 'optimizacion', 'modelado',
    'trabajo_equipo', 'comunicacion', 'creatividad', 'adaptabilidad', 'liderazgo', 'resolucion_problemas'
]
# Crear DataFrame
df = pd.DataFrame(np.concatenate([tec, mat, psi], axis=1), columns=columnas)

# %%
# Calcular promedio por grupo y promedio total
prom_tecnologicas = df[['python', 'sql', 'visualizacion_datos', 'excel', 'manejo_apis', 'nube']].mean(axis=1)
prom_matematicas  = df[['estadistica', 'probabilidad', 'algebra_lineal', 'calculo', 'optimizacion', 'modelado']].mean(axis=1)
prom_psicologicas = df[['trabajo_equipo', 'comunicacion', 'creatividad', 'adaptabilidad', 'liderazgo', 'resolucion_problemas']].mean(axis=1)
# Promedio total = promedio de los 3 promedios
prom_total = (prom_tecnologicas + prom_matematicas + prom_psicologicas) / 3
# Etiqueta: 1 = apto si promedio total > 80
y = (prom_total > 75).astype(int)
# one-hot encoding
y = pd.get_dummies(y).values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    df, y, test_size=0.2, random_state=42
)

# Escalamiento
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
modelo = Sequential([
    Dense(64, input_shape=(X_train.shape[1],), activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(2, activation='softmax')
])

adam = Adam(learning_rate=0.001)
modelo.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = modelo.fit(
    X_train, y_train,
    epochs=50,
    batch_size=8,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7933 - loss: 0.4102 - val_accuracy: 0.9680 - val_loss: 0.0893
# Epoch 2/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9713 - loss: 0.0733 - val_accuracy: 0.9750 - val_loss: 0.0600
# Epoch 3/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9840 - loss: 0.0454 - val_accuracy: 0.9840 - val_loss: 0.0487
# Epoch 4/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9880 - loss: 0.0322 - val_accuracy: 0.9810 - val_loss: 0.0420
# Epoch 5/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9917 - loss: 0.0209 - val_accuracy: 0.9770 - val_loss: 0.0518
# Epoch 6/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9891 - loss: 0.0234 - val_accuracy: 0.9810 - val_loss: 0.0389
# Epoch 7/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9920 - loss: 0.0187 - val_accuracy: 0.9760 - val_loss: 0.0724
# Epoch 8/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9929 - loss: 0.0182 - val_accuracy: 0.9860 - val_loss: 0.0438
# Epoch 9/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9954 - loss: 0.0150 - val_accuracy: 0.9840 - val_loss: 0.0461
# Epoch 10/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9934 - loss: 0.0161 - val_accuracy: 0.9790 - val_loss: 0.0541
# Epoch 11/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9960 - loss: 0.0109 - val_accuracy: 0.9820 - val_loss: 0.0501
# Epoch 12/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9973 - loss: 0.0081 - val_accuracy: 0.9800 - val_loss: 0.0542
# Epoch 13/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9999 - loss: 0.0023 - val_accuracy: 0.9830 - val_loss: 0.0485
# Epoch 14/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9850 - val_loss: 0.0499
# Epoch 15/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 1.0000 - loss: 8.3607e-04 - val_accuracy: 0.9850 - val_loss: 0.0476
# Epoch 16/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 4.5904e-04 - val_accuracy: 0.9860 - val_loss: 0.0451
# Epoch 17/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 3.7742e-04 - val_accuracy: 0.9850 - val_loss: 0.0494
# Epoch 18/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 1.9286e-04 - val_accuracy: 0.9850 - val_loss: 0.0504
# Epoch 19/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 1.1376e-04 - val_accuracy: 0.9860 - val_loss: 0.0498
# Epoch 20/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 1.1066e-04 - val_accuracy: 0.9860 - val_loss: 0.0525
# Epoch 21/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 7.2776e-05 - val_accuracy: 0.9860 - val_loss: 0.0553
# Epoch 22/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 5.0410e-05 - val_accuracy: 0.9860 - val_loss: 0.0575
# Epoch 23/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 3.6113e-05 - val_accuracy: 0.9860 - val_loss: 0.0572
# Epoch 24/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 4.0644e-05 - val_accuracy: 0.9860 - val_loss: 0.0563
# Epoch 25/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.4236e-05 - val_accuracy: 0.9860 - val_loss: 0.0587
# Epoch 26/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 1.0000 - loss: 1.6001e-05 - val_accuracy: 0.9860 - val_loss: 0.0594
# Epoch 27/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.0489e-05 - val_accuracy: 0.9860 - val_loss: 0.0609
# Epoch 28/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 9.6285e-06 - val_accuracy: 0.9860 - val_loss: 0.0624
# Epoch 29/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 6.1328e-06 - val_accuracy: 0.9860 - val_loss: 0.0663
# Epoch 30/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 3.8722e-06 - val_accuracy: 0.9860 - val_loss: 0.0679
# Epoch 31/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 4.1114e-06 - val_accuracy: 0.9860 - val_loss: 0.0680
# Epoch 32/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 2.4718e-06 - val_accuracy: 0.9870 - val_loss: 0.0680
# Epoch 33/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.0123e-06 - val_accuracy: 0.9860 - val_loss: 0.0736
# Epoch 34/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 1.4316e-06 - val_accuracy: 0.9870 - val_loss: 0.0718
# Epoch 35/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 8.5104e-07 - val_accuracy: 0.9860 - val_loss: 0.0735
# Epoch 36/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 7.2325e-07 - val_accuracy: 0.9870 - val_loss: 0.0755
# Epoch 37/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 4.5469e-07 - val_accuracy: 0.9860 - val_loss: 0.0793
# Epoch 38/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 1.0000 - loss: 3.5505e-07 - val_accuracy: 0.9860 - val_loss: 0.0789
# Epoch 39/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.5584e-07 - val_accuracy: 0.9870 - val_loss: 0.0799
# Epoch 40/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 2.1370e-07 - val_accuracy: 0.9870 - val_loss: 0.0825
# Epoch 41/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 1.3050e-07 - val_accuracy: 0.9880 - val_loss: 0.0837
# Epoch 42/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 1.1091e-07 - val_accuracy: 0.9870 - val_loss: 0.0864
# Epoch 43/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 8.4238e-08 - val_accuracy: 0.9870 - val_loss: 0.0853
# Epoch 44/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 4.3770e-08 - val_accuracy: 0.9870 - val_loss: 0.0884
# Epoch 45/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 1.0000 - loss: 5.0262e-08 - val_accuracy: 0.9870 - val_loss: 0.0898
# Epoch 46/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 3.8582e-08 - val_accuracy: 0.9870 - val_loss: 0.0909
# Epoch 47/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 2.5780e-08 - val_accuracy: 0.9870 - val_loss: 0.0951
# Epoch 48/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 1.8942e-08 - val_accuracy: 0.9870 - val_loss: 0.0937
# Epoch 49/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 1.4076e-08 - val_accuracy: 0.9860 - val_loss: 0.0967
# Epoch 50/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 1.1942e-08 - val_accuracy: 0.9870 - val_loss: 0.0966

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Pérdida de entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida de validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()
plt.title('Evolución de la función de pérdida')
plt.show()

loss, acc = modelo.evaluate(X_test, y_test)
print(f"\n🔹 Loss: {loss:.4f}  |  Accuracy: {acc:.4f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9876 - loss: 0.0871
#
# 🔹 Loss: 0.0966  |  Accuracy: 0.9870

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, recall_score

pred = modelo.predict(X_test)
y_pred = np.argmax(pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['No Apto', 'Apto'])
disp.plot(cmap='Blues')
plt.show()

sensitivity = recall_score(y_true, y_pred, average=None)
print("\nSensitivity (Recall) por clase:")
print(f"No Apto: {sensitivity[0]:.2f}")
print(f"Apto: {sensitivity[1]:.2f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Sensitivity (Recall) por clase:
# No Apto: 0.99
# Apto: 0.99

# %%
nuevo_candidato = np.array([[90, 88, 85, 87, 84, 89,   # técnicas
                             82, 86, 85, 83, 87, 80,   # matemáticas
                             70, 75, 80, 72, 78, 74]]) # psicológicas

nuevo_candidato_scaled = scaler.transform(nuevo_candidato)
pred_nuevo = modelo.predict(nuevo_candidato_scaled)
clase_predicha = np.argmax(pred_nuevo)

print("Evaluación de nuevo candidato:")
print(f"Resultado: {'Apto' if clase_predicha == 1 else 'No Apto'}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Evaluación de nuevo candidato:
# Resultado: Apto
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
